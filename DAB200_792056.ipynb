# %%
import numpy as np
import pandas as pd
import sklearn

# %%
play = pd.read_csv(r"D:\Study\Sem 2\DAB200\playstore_games_final.csv",encoding='latin1')
play.head(2)
# Out:
#                             title  total_ratings  install_million  avg_rating  \
# 0  Garena Free Fire- World Series     86273129.0            500.0         4.0
# 1                  Clash of Clans     55766763.0            500.0         4.0
#
#    growth_30days  growth_60days  Category  5_star_rating  4_star_rating  \
# 0            2.1            6.9    Action     63546766.0      4949507.0
# 1            0.3            1.0  Strategy     43346128.0      5404966.0
#
#    3_star_rating  2_star_rating  1_star_rating  price   paid
# 0      3158756.0      2122183.0     12495915.0    0.0  False
# 1      2276203.0       971321.0      3768141.0    0.0  False
